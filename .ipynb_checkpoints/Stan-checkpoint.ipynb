# %%
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
#Load in the data set
FifaDB = pd.read_csv("NewFifa.csv")

# %%
#Explore dataset
FifaDB
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage Preferred Foot  Weak Foot  ...  \
# 0             FC Barcelona  €110.5M  €565K           Left        4.0  ...
# ...

# %%
#Split dataset
from sklearn.model_selection import train_test_split
fifatrain, fifatest = train_test_split(FifaDB, test_size=0.25)

# %%
fifatrain["Work Rate"]
# Out:
# 14158    Medium/ Medium
# 6276       Medium/ High
# 17463    Medium/ Medium
# 13621        High/ High
# 15342       Medium/ Low
#               ...
# 15162    Medium/ Medium
# 6862         High/ High
# 10371    Medium/ Medium
# 9688       High/ Medium
# 4421     Medium/ Medium
# Name: Work Rate, Length: 13655, dtype: object

# %%
fifatrain.info()
#One Hot --> Work rate, Body Type, Position
#Numerical --> Value, Wage,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13655 entries, 14158 to 4421
# Data columns (total 52 columns):
# Name               13655 non-null object
# Age                13655 non-null int64
# Nationality        13655 non-null object
# Overall            13655 non-null int64
# Potential          13655 non-null int64
# Club               13468 non-null object
# Value              13655 non-null object
# Wage               13655 non-null object
# Preferred Foot     13622 non-null object
# Weak Foot          13622 non-null float64
# Skill Moves        13622 non-null float64
# Work Rate          13622 non-null object
# Body Type          13622 non-null object
# Position           13611 non-null object
# Jersey Number      13611 non-null float64
# Height             13622 non-null object
# Weight             13622 non-null object
# Crossing           13622 non-null float64
# Finishing          13622 non-null float64
# HeadingAccuracy    13622 non-null float64
# ...

# %%
#Encode position to correlate
df_encoded = pd.get_dummies(data=fifatrain, columns=obj_columns)
df_encoded
