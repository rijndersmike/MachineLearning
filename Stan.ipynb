# %%
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
#Load in the data set
FifaDB = pd.read_csv("NewFifa.csv")

# %%
#Explore dataset
FifaDB
# Out:
#        Overall  Potential    Value   Wage Preferred Foot  Weak Foot  \
# 0           94         94  €110.5M  €565K           Left        4.0
# 1           94         94     €77M  €405K          Right        4.0
# 2           92         93  €118.5M  €290K          Right        5.0
# 3           91         93     €72M  €260K          Right        3.0
# 4           91         92    €102M  €355K          Right        5.0
# ...        ...        ...      ...    ...            ...        ...
# 18202       47         65     €60K    €1K          Right        2.0
# 18203       47         63     €60K    €1K          Right        2.0
# 18204       47         67     €60K    €1K          Right        3.0
# 18205       47         66     €60K    €1K          Right        3.0
# 18206       46         66     €60K    €1K          Right        3.0
#
#        Skill Moves       Work Rate   Body Type Position  ...  Penalties  \
# 0              4.0  Medium/ Medium       Messi       RF  ...       75.0
# 1              5.0       High/ Low  C. Ronaldo       ST  ...       85.0
# 2              5.0    High/ Medium      Neymar       LW  ...       81.0
# 3              1.0  Medium/ Medium        Lean       GK  ...       40.0
# 4              4.0      High/ High      Normal      RCM  ...       79.0
# ...            ...             ...         ...      ...  ...        ...
# 18202          2.0  Medium/ Medium        Lean       CM  ...       43.0
# 18203          2.0  Medium/ Medium      Normal       ST  ...       43.0
# 18204          2.0  Medium/ Medium      Normal       ST  ...       55.0
# 18205          2.0  Medium/ Medium        Lean       RW  ...       50.0
# 18206          2.0  Medium/ Medium        Lean       CM  ...       33.0
#
#       Composure Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0          96.0    33.0            28.0           26.0       6.0        11.0
# 1          95.0    28.0            31.0           23.0       7.0        11.0
# 2          94.0    27.0            24.0           33.0       9.0         9.0
# 3          68.0    15.0            21.0           13.0      90.0        85.0
# 4          88.0    68.0            58.0           51.0      15.0        13.0
# ...         ...     ...             ...            ...       ...         ...
# 18202      45.0    40.0            48.0           47.0      10.0        13.0
# 18203      42.0    22.0            15.0           19.0      10.0         9.0
# 18204      41.0    32.0            13.0           11.0       6.0         5.0
# 18205      46.0    20.0            25.0           27.0      14.0         6.0
# 18206      43.0    40.0            43.0           50.0      10.0        15.0
#
#        GKKicking  GKPositioning  GKReflexes
# 0           15.0           14.0         8.0
# 1           15.0           14.0        11.0
# 2           15.0           15.0        11.0
# 3           87.0           88.0        94.0
# 4            5.0           10.0        13.0
# ...          ...            ...         ...
# 18202        7.0            8.0         9.0
# 18203        9.0            5.0        12.0
# 18204       10.0            6.0        13.0
# 18205       14.0            8.0         9.0
# 18206        9.0           12.0         9.0
#
# [18207 rows x 47 columns]

# %%
#Split dataset
from sklearn.model_selection import train_test_split
fifatrain, fifatest = train_test_split(FifaDB, test_size=0.25)

# %%
fifatrain.info()
#One Hot --> Work rate, Body Type, Position, Preffered foot
#Numerical --> Value, Wage,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13655 entries, 9631 to 13012
# Data columns (total 47 columns):
# Overall            13655 non-null int64
# Potential          13655 non-null int64
# Value              13655 non-null object
# Wage               13655 non-null object
# Preferred Foot     13619 non-null object
# Weak Foot          13619 non-null float64
# Skill Moves        13619 non-null float64
# Work Rate          13619 non-null object
# Body Type          13619 non-null object
# Position           13610 non-null object
# Jersey Number      13610 non-null float64
# Height             13619 non-null object
# Weight             13619 non-null object
# Crossing           13619 non-null float64
# Finishing          13619 non-null float64
# HeadingAccuracy    13619 non-null float64
# ShortPassing       13619 non-null float64
# Volleys            13619 non-null float64
# Dribbling          13619 non-null float64
# Curve              13619 non-null float64
# FKAccuracy         13619 non-null float64
# LongPassing        13619 non-null float64
# BallControl        13619 non-null float64
# Acceleration       13619 non-null float64
# SprintSpeed        13619 non-null float64
# Agility            13619 non-null float64
# Reactions          13619 non-null float64
# Balance            13619 non-null float64
# ShotPower          13619 non-null float64
# Jumping            13619 non-null float64
# Stamina            13619 non-null float64
# Strength           13619 non-null float64
# LongShots          13619 non-null float64
# Aggression         13619 non-null float64
# Interceptions      13619 non-null float64
# Positioning        13619 non-null float64
# Vision             13619 non-null float64
# Penalties          13619 non-null float64
# Composure          13619 non-null float64
# Marking            13619 non-null float64
# StandingTackle     13619 non-null float64
# SlidingTackle      13619 non-null float64
# GKDiving           13619 non-null float64
# GKHandling         13619 non-null float64
# GKKicking          13619 non-null float64
# GKPositioning      13619 non-null float64
# GKReflexes         13619 non-null float64
# dtypes: float64(37), int64(2), object(8)
# memory usage: 4.6+ MB

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-dffa4af8a32c> in <module>()
#       1 #Encode position to correlate
# ----> 2 df_encoded = pd.get_dummies(data=fifatrain, columns=obj_columns)
#       3 df_encoded
#
# NameError: name 'obj_columns' is not defined
