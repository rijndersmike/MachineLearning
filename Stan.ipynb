# %%
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.model_selection import train_test_split

# %%
#Load in the data set
FifaDB = pd.read_csv("NewFifa.csv")
FifaDB.set_index('Name', inplace=True)

# %%
#Explore datase
FifaDB
# Out:
#                     Overall  Potential    Value   Wage  Weak Foot  \
# Name
# L. Messi                 94         94  €110.5M  €565K        4.0
# Cristiano Ronaldo        94         94     €77M  €405K        4.0
# Neymar Jr                92         93  €118.5M  €290K        5.0
# De Gea                   91         93     €72M  €260K        3.0
# K. De Bruyne             91         92    €102M  €355K        5.0
# ...                     ...        ...      ...    ...        ...
# J. Lundstram             47         65     €60K    €1K        2.0
# N. Christoffersson       47         63     €60K    €1K        2.0
# B. Worman                47         67     €60K    €1K        3.0
# D. Walker-Rice           47         66     €60K    €1K        3.0
# G. Nugent                46         66     €60K    €1K        3.0
#
#                     Skill Moves Position  Jersey Number Height  Weight  ...  \
# Name                                                                    ...
# L. Messi                    4.0       RF           10.0    5'7  159lbs  ...
# Cristiano Ronaldo           5.0       ST            7.0    6'2  183lbs  ...
# Neymar Jr                   5.0       LW           10.0    5'9  150lbs  ...
# De Gea                      1.0       GK            1.0    6'4  168lbs  ...
# K. De Bruyne                4.0      RCM            7.0   5'11  154lbs  ...
# ...                         ...      ...            ...    ...     ...  ...
# J. Lundstram                2.0       CM           22.0    5'9  134lbs  ...
# N. Christoffersson          2.0       ST           21.0    6'3  170lbs  ...
# B. Worman                   2.0       ST           33.0    5'8  148lbs  ...
# D. Walker-Rice              2.0       RW           34.0   5'10  154lbs  ...
# G. Nugent                   2.0       CM           33.0   5'10  176lbs  ...
#
#                     Body Type_Akinfenwa  Body Type_C. Ronaldo  \
# Name
# L. Messi                              0                     0
# Cristiano Ronaldo                     0                     1
# Neymar Jr                             0                     0
# De Gea                                0                     0
# K. De Bruyne                          0                     0
# ...                                 ...                   ...
# J. Lundstram                          0                     0
# N. Christoffersson                    0                     0
# B. Worman                             0                     0
# D. Walker-Rice                        0                     0
# G. Nugent                             0                     0
#
#                     Body Type_Courtois  Body Type_Lean  Body Type_Messi  \
# Name
# L. Messi                             0               0                1
# Cristiano Ronaldo                    0               0                0
# Neymar Jr                            0               0                0
# De Gea                               0               1                0
# K. De Bruyne                         0               0                0
# ...                                ...             ...              ...
# J. Lundstram                         0               1                0
# N. Christoffersson                   0               0                0
# B. Worman                            0               0                0
# D. Walker-Rice                       0               1                0
# G. Nugent                            0               1                0
#
#                     Body Type_Neymar  Body Type_Normal  \
# Name
# L. Messi                           0                 0
# Cristiano Ronaldo                  0                 0
# Neymar Jr                          1                 0
# De Gea                             0                 0
# K. De Bruyne                       0                 1
# ...                              ...               ...
# J. Lundstram                       0                 0
# N. Christoffersson                 0                 1
# B. Worman                          0                 1
# D. Walker-Rice                     0                 0
# G. Nugent                          0                 0
#
#                     Body Type_PLAYER_BODY_TYPE_25  Body Type_Shaqiri  \
# Name
# L. Messi                                        0                  0
# Cristiano Ronaldo                               0                  0
# Neymar Jr                                       0                  0
# De Gea                                          0                  0
# K. De Bruyne                                    0                  0
# ...                                           ...                ...
# J. Lundstram                                    0                  0
# N. Christoffersson                              0                  0
# B. Worman                                       0                  0
# D. Walker-Rice                                  0                  0
# G. Nugent                                       0                  0
#
#                     Body Type_Stocky
# Name
# L. Messi                           0
# Cristiano Ronaldo                  0
# Neymar Jr                          0
# De Gea                             0
# K. De Bruyne                       0
# ...                              ...
# J. Lundstram                       0
# N. Christoffersson                 0
# B. Worman                          0
# D. Walker-Rice                     0
# G. Nugent                          0
#
# [18207 rows x 65 columns]

# %%
#Select target and split dataset
Features = FifaDB.iloc[:,0:199]
Target = FifaDB.iloc[:,6]
# Out:
# Name
# L. Messi              91.0
# Cristiano Ronaldo     89.0
# Neymar Jr             94.0
# De Gea                57.0
# K. De Bruyne          78.0
#                       ...
# J. Lundstram          54.0
# N. Christoffersson    41.0
# B. Worman             70.0
# D. Walker-Rice        61.0
# G. Nugent             57.0
# Name: Acceleration, Length: 18207, dtype: float64

# %%
# #Checking correlations for certain positions
# plt.figure(figsize=(12,10))
# cor = FifaDB.corr()
# sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
# #Correlation with output variable
# cor_target = abs(cor["Position_CB"])
# #Selecting highly correlated features
# relevant_features = cor_target[cor_target>0.2]
# relevant_features

# %%
#Random Forest
print("The shape of our features is:", features.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-a43843be6cab> in <module>()
#       1 #Random Forest
# ----> 2 print("The shape of our features is:", features.shape)
#
# NameError: name 'features' is not defined
