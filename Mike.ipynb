# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
FifaDB = pd.read_csv('NewFifa.csv')

# %%
from sklearn.model_selection import train_test_split
fifatrain, fifatest = train_test_split(FifaDB, test_size = 0.25)

# %%
FifaDB
# Out:
#                      Name  Overall  Potential    Value   Wage  Weak Foot  \
# 0                L. Messi       94         94  €110.5M  €565K        4.0
# 1       Cristiano Ronaldo       94         94     €77M  €405K        4.0
# 2               Neymar Jr       92         93  €118.5M  €290K        5.0
# 3                  De Gea       91         93     €72M  €260K        3.0
# 4            K. De Bruyne       91         92    €102M  €355K        5.0
# ...                   ...      ...        ...      ...    ...        ...
# 18202        J. Lundstram       47         65     €60K    €1K        2.0
# 18203  N. Christoffersson       47         63     €60K    €1K        2.0
# 18204           B. Worman       47         67     €60K    €1K        3.0
# 18205      D. Walker-Rice       47         66     €60K    €1K        3.0
# 18206           G. Nugent       46         66     €60K    €1K        3.0
#
#        Skill Moves Position  Jersey Number Height  ... Body Type_Akinfenwa  \
# ...

# %%
FifaDB['Height']
# Out:
# 0         5'7
# 1         6'2
# 2         5'9
# 3         6'4
# 4        5'11
#          ...
# 18202     5'9
# 18203     6'3
# 18204     5'8
# 18205    5'10
# 18206    5'10
# Name: Height, Length: 18207, dtype: object

# %%
FifaDB['Height']
# Out:
# 0         5'7
# 1         6'2
# 2         5'9
# 3         6'4
# 4        5'11
#          ...
# 18202     5'9
# 18203     6'3
# 18204     5'8
# 18205    5'10
# 18206    5'10
# Name: Height, Length: 18207, dtype: object

# %%
list_length = FifaDB['Height']
list_centimeters = []
for item in list_length:
    list_centimeters = []
    splitted_values = str(item).split(" ' ")
    for x in splitted_values:
        feet = (float(x[0])) + (float(x[2])/10)
        centimeters = feet * 30.48
        print(centimeters)
# Out:
# 173.73600000000002
# 188.976
# 179.83200000000002
# 195.072
# 155.44799999999998
# 176.784
# 176.784
# 182.88
# 182.88
# 188.976
# 182.88
# 182.88
# 188.976
# 176.784
# 170.688
# 155.44799999999998
# 188.976
# 179.83200000000002
# 188.976
# 201.16799999999998
# 188.976
# 185.928
# 195.072
# 176.784
# 188.976
# 155.44799999999998
# 179.83200000000002
# 185.928
# 155.44799999999998
# 164.592
# 179.83200000000002
# 155.44799999999998
# 176.784
# 188.976
# 192.024
# 179.83200000000002
# 185.928
# 188.976
# 185.928
# 182.88
# 195.072
# 195.072
# 182.88
# 155.44799999999998
# 188.976
# 195.072
# 185.928
# 192.024
# 185.928
# 173.73600000000002
# 173.73600000000002
# 188.976
# 182.88
# 182.88
# 195.072
# 182.88
# 176.784
# 188.976
# 179.83200000000002
# 195.072
# 173.73600000000002
# 155.44799999999998
# 192.024
# 167.64000000000001
# 155.44799999999998
# 176.784
# 185.928
# 179.83200000000002
# 155.44799999999998
# 155.44799999999998
# 192.024
# 185.928
# 155.44799999999998
# 188.976
# ...

# %%
list_lengths1 = np.array(FifaDB['Height'])
empty_list = []
for x in list_lengths1:
    splitted_values = x.split("'")
    feet = (float(x[0])) + (float(x[2])/10)
    centimeters = feet * 30.48
    
    
return empty_list.append(centimeters)
print(empty_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-3345bc102943> in <module>()
#       2 empty_list = []
#       3 for x in list_lengths1:
# ----> 4     splitted_values = x.split("'")
#       5     feet = (float(x[0])) + (float(x[2])/10)
#       6     centimeters = feet * 30.48
#
# AttributeError: 'float' object has no attribute 'split'
